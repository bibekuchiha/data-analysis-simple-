# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/list-of-video-games-considered-the-best/video_games_considered_the_best.csv

# %%
game = pd.read_csv('/kaggle/input/list-of-video-games-considered-the-best/video_games_considered_the_best.csv')
game.head()
# Out:
#    Unnamed: 0  year           title             genre publisher   plataform  \
# 0           0  1972            Pong            Sports     Atari      Arcade
# 1           1  1977            Zork         Adventure   Infocom      PDP-10
# 2           2  1978  Space Invaders      Shoot 'em up     Taito      Arcade
# 3           3  1979       Asteroids      Shoot 'em up     Atari      Arcade
# 4           4  1980       Adventure  Action-adventure     Atari  Atari 2600
#
#    refs
# 0    13
# 1     9
# 2    16
# 3    12
# 4     7

# %% [markdown]
# lets drop column Unnamed: 0 because it is not doing any important role

# %%
del game['Unnamed: 0']

# %%
game
# Out:
#      year                                    title                 genre  \
# 0    1972                                     Pong                Sports
# 1    1977                                     Zork             Adventure
# 2    1978                           Space Invaders          Shoot 'em up
# 3    1979                                Asteroids          Shoot 'em up
# 4    1980                                Adventure      Action-adventure
# ..    ...                                      ...                   ...
# 190  2015                               Bloodborne   Action role-playing
# 191  2015                 The Witcher 3: Wild Hunt   Action role-playing
# 192  2016                                   Inside              Platform
# 193  2016                                Overwatch  First-person shooter
# 194  2017  The Legend of Zelda: Breath of the Wild      Action-adventure
#
#                        publisher                    plataform  refs
# ...

# %% [markdown]
# lets find out how many rows and columns are there in data set

# %%
game.shape
# Out:
# (195, 6)

# %% [markdown]
# After finding there are total 195 rows in dataset.
# Now lets find how many genres are there in game

# %%
game['genre'].value_counts()
# Out:
# Action-adventure          31
# Platform                  22
# First-person shooter      20
# Role-playing              15
# Action role-playing       12
# Adventure                 10
# Shoot 'em up              10
# Stealth                    8
# Fighting                   8
# Real-time strategy         6
# Sports                     5
# Survival horror            5
# Racing                     5
# Action                     5
# Turn-based strategy        4
# Puzzle-platformer          3
# Puzzle                     2
# Maze                       2
# MMORPG                     2
# City-building              2
# Space flight simulator     2
# Third-person shooter       2
# Life simulation            2
# Rhythm                     2
# MOBA                       1
# Real-time tactics          1
# Sandbox                    1
# Tactical role-playing      1
# Turn-based tactics         1
# Top-down shooter           1
# Strategy                   1
# Run and gun                1
# ...

# %%
import matplotlib.pyplot as plt

game['genre'].value_counts()[:20].plot(kind='barh')

# %% [markdown]
# As from the figure we know that action-adventure type of game is mostly considered as a best among all genre

# %%
game
# Out:
#      year                                    title                 genre  \
# 0    1972                                     Pong                Sports
# 1    1977                                     Zork             Adventure
# 2    1978                           Space Invaders          Shoot 'em up
# 3    1979                                Asteroids          Shoot 'em up
# 4    1980                                Adventure      Action-adventure
# ..    ...                                      ...                   ...
# 190  2015                               Bloodborne   Action role-playing
# 191  2015                 The Witcher 3: Wild Hunt   Action role-playing
# 192  2016                                   Inside              Platform
# 193  2016                                Overwatch  First-person shooter
# 194  2017  The Legend of Zelda: Breath of the Wild      Action-adventure
#
#                        publisher                    plataform  refs
# ...

# %%
game['plataform'].value_counts()[:20].plot(kind='barh')

# %% [markdown]
# As from the above chart , it can be clearly observe that there are more numbers of pc gamer in the world with mucg high number that others in compare to playstation, xbox and so on

# %%
game
# Out:
#      year                                    title                 genre  \
# 0    1972                                     Pong                Sports
# 1    1977                                     Zork             Adventure
# 2    1978                           Space Invaders          Shoot 'em up
# 3    1979                                Asteroids          Shoot 'em up
# 4    1980                                Adventure      Action-adventure
# ..    ...                                      ...                   ...
# 190  2015                               Bloodborne   Action role-playing
# 191  2015                 The Witcher 3: Wild Hunt   Action role-playing
# 192  2016                                   Inside              Platform
# 193  2016                                Overwatch  First-person shooter
# 194  2017  The Legend of Zelda: Breath of the Wild      Action-adventure
#
#                        publisher                    plataform  refs
# ...

# %%
game['publisher'].value_counts()
# Out:
# Nintendo                                  30
# Sega                                      11
# Sony Computer Entertainment               10
# Capcom                                     8
# LucasArts                                  8
# Valve                                      8
# Blizzard Entertainment                     7
# Konami                                     6
# Rockstar Games                             6
# Namco                                      6
# Microsoft Game Studios                     6
# Square                                     6
# Electronic Arts                            6
# Eidos Interactive                          5
# Activision                                 5
# Ubisoft                                    4
# Bethesda Softworks                         4
# Atari                                      4
# Midway                                     4
# Interplay Entertainment                    3
# MicroProse                                 3
# ...

# %%
game['publisher'].value_counts()[:20].plot(kind='barh')

# %% [markdown]
# As from the figure it can be seen that Nintendo published most best game among all

# %%
game['year'].value_counts()
# Out:
# 2001    13
# 1993    13
# 1998    10
# 1997    10
# 2000     9
# 1996     9
# 2005     8
# 2008     8
# 1999     8
# 2010     7
# 2004     7
# 1991     7
# 2007     7
# 1994     6
# 2006     5
# 2002     5
# 2011     5
# 2003     4
# 1987     4
# 1982     4
# 2009     4
# 1992     4
# 1981     3
# 1984     3
# 1986     3
# 1980     3
# 1995     3
# 2013     3
# 2012     3
# 1989     2
# 1988     2
# 1990     2
# 2015     2
# 1985     2
# 2016     2
# 1978     1
# 1977     1
# 2017     1
# 1979     1
# 1972     1
# Name: year, dtype: int64

# %%
#Best fighting games from the list
fighting_games = game[game['genre'] == 'Fighting']
fighting_games
# Out:
#      year                    title     genre publisher plataform  refs
# 38   1991        Street Fighter II  Fighting    Capcom    Arcade    31
# 39   1992            Mortal Kombat  Fighting    Midway    Arcade     7
# 47   1993         Mortal Kombat II  Fighting    Midway    Arcade    10
# 83   1997                 Tekken 3  Fighting     Namco    Arcade     9
# 91   1998              SoulCalibur  Fighting     Namco    Arcade    13
# 123  2001  Super Smash Bros. Melee  Fighting  Nintendo  GameCube    18
# 128  2002           Soulcalibur II  Fighting     Namco    Arcade     7
# 167  2008        Street Fighter IV  Fighting    Capcom    Arcade    11

# %%
#Best sports games from the list
sports_games = game[game['genre'] == 'Sports']
sports_games
# Out:
#      year                     title   genre   publisher    plataform  refs
# 0    1972                      Pong  Sports       Atari       Arcade    13
# 24   1987  Mike Tyson's Punch-Out!!  Sports    Nintendo          NES    15
# 49   1993                   NBA Jam  Sports      Midway       Arcade    13
# 110  2000  Tony Hawk's Pro Skater 2  Sports  Activision  PlayStation    11
# 152  2006                Wii Sports  Sports    Nintendo          Wii     8

# %%
#Best action-adv games from the list
aa_games = game[game['genre'] == 'Action-adventure']
aa_games
# Out:
#      year                                    title             genre  \
# 4    1980                                Adventure  Action-adventure
# 20   1986                      The Legend of Zelda  Action-adventure
# 34   1991  The Legend of Zelda: A Link to the Past  Action-adventure
# 46   1993    The Legend of Zelda: Link's Awakening  Action-adventure
# 60   1994                            Super Metroid  Action-adventure
# 73   1996                              Tomb Raider  Action-adventure
# 74   1997       Castlevania: Symphony of the Night  Action-adventure
# 87   1998     The Legend of Zelda: Ocarina of Time  Action-adventure
# 107  2000       The Legend of Zelda: Majora's Mask  Action-adventure
# 115  2001                     Grand Theft Auto III  Action-adventure
# 117  2001                                      Ico  Action-adventure
# 124  2002              Grand Theft Auto: Vice City  Action-adventure
# 126  2002      The Legend of Zelda: The Wind Waker  Action-adventure
# ...
